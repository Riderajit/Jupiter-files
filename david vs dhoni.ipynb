# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

#to display all rows columns 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

# %%
df = pd.read_csv('ODI_data.csv')

# %%
df.head(10)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate
# ...

# %%
len(df), len(df.columns)
# Out:
# (171968, 28)

# %%
# Runs per innings
# SR
# 100's
# 50's
# Team contribution

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '-', nan, '40', '6', '4', '87', '54', '46',
#        '30', '12', '69', '39', '14', '10', '9', '8', '7', '82', '52',
#        '41', '15', '98', '43', '19', '111', '48', '36', '25', '67', '60',
#        '84', '59', '55', '47', '85', '49', '45', '34', '29', '22', '74',
#        '28', '77', '50', '32', '23', '35', '122', '100', '95', '103',
#        '113', '53', '96', '27', '64', '58', '33', '31', '73', '56', '86',
#        '62', '106', '24', '57', '104', '26', '66', '51', '118', '105',
#        '101', '21', '79', '44', '102', '88', '80', '72', '97', '68', '89',
#        '38', '83', '63', '148', '166', '90', '76', '37', '70', '124',
#        '94', '140', '153', '107', '117', '121', '92', '78', '75', '114',
#        '115', '130', '128', '151', '110', '138', '135', '109', '61',
#        '179', '170', '112', '116', '91', '143', '93', '123', '145', '81',
# ...

# %%
df = df[df['Innings Runs Scored Num'] != '-']

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', nan, '40', '6', '4', '87', '54', '46', '30',
#        '12', '69', '39', '14', '10', '9', '8', '7', '82', '52', '41',
#        '15', '98', '43', '19', '111', '48', '36', '25', '67', '60', '84',
#        '59', '55', '47', '85', '49', '45', '34', '29', '22', '74', '28',
#        '77', '50', '32', '23', '35', '122', '100', '95', '103', '113',
#        '53', '96', '27', '64', '58', '33', '31', '73', '56', '86', '62',
#        '106', '24', '57', '104', '26', '66', '51', '118', '105', '101',
#        '21', '79', '44', '102', '88', '80', '72', '97', '68', '89', '38',
#        '83', '63', '148', '166', '90', '76', '37', '70', '124', '94',
#        '140', '153', '107', '117', '121', '92', '78', '75', '114', '115',
#        '130', '128', '151', '110', '138', '135', '109', '61', '179',
#        '170', '112', '116', '91', '143', '93', '123', '145', '81', '150',
# ...

# %%
df = df.dropna(subset = ['Innings Runs Scored Num'])

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '40', '6', '4', '87', '54', '46', '30', '12',
#        '69', '39', '14', '10', '9', '8', '7', '82', '52', '41', '15',
#        '98', '43', '19', '111', '48', '36', '25', '67', '60', '84', '59',
#        '55', '47', '85', '49', '45', '34', '29', '22', '74', '28', '77',
#        '50', '32', '23', '35', '122', '100', '95', '103', '113', '53',
#        '96', '27', '64', '58', '33', '31', '73', '56', '86', '62', '106',
#        '24', '57', '104', '26', '66', '51', '118', '105', '101', '21',
#        '79', '44', '102', '88', '80', '72', '97', '68', '89', '38', '83',
#        '63', '148', '166', '90', '76', '37', '70', '124', '94', '140',
#        '153', '107', '117', '121', '92', '78', '75', '114', '115', '130',
#        '128', '151', '110', '138', '135', '109', '61', '179', '170',
#        '112', '116', '91', '143', '93', '123', '145', '81', '150', '162',
# ...

# %%
df.head(1)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate
# ...

# %%
# convert to datetime
df['Innings Date'] = pd.to_datetime(df['Innings Date'])

# %%
df['year'] = df['Innings Date'].dt.year

# %%
df.tail(1)
# Out:
#        Innings Player Innings Runs Scored Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition     Ground Innings Date    Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
df['Innings Runs Scored Num'] = df['Innings Runs Scored Num'].astype('int')

# %%
df['Innings Balls Faced'] = df['Innings Balls Faced'].astype('int')

# %%
df['Innings Not Out Flag'] = df['Innings Not Out Flag'].astype('int')

# %%
# david 1997 - 2007
# dhoni 2005 - 2016

# %%
david_df = df[(df.year >= 1997) & (df.year <= 2005)]

# %%
dhoni_df = df[(df.year >= 2005) & (df.year <= 2013)]

# %%
david_df.head(2)
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number   Opposition      Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
dhoni_df.head(2)
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number   Opposition     Ground Innings Date   Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
# Runs per innings = Total Runs/Total Innings
# SR = 100*(Total Runs/Total Balls)
# 100's = sum(100's)
# 50's = sum(50's)
# Team contribution = Player Runs/Team Runs (ex: dhoni 50/ Team Ind 150 => 50/150 : 33%)

# %%
# df.dtypes

# %%
# david_df.to_csv('david_data.csv')

# %%
# what is the total runs scored by david in these time frames?

# %%
david_df.head(200)
# Out:
#          Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number      Opposition        Ground Innings Date       Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
# R Dravid
sdf = david_df[david_df['Innings Player'] == 'R Dravid']

# %%
sdf.head()
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number      Opposition              Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
sum(sdf['Innings Runs Scored Num'])
# Out:
# 8247

# %%
mdf = sdf = david_df[david_df['Innings Player'] == 'R Dravid']

# %%
dhoni_df.head(300)
# Out:
#          Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number      Opposition          Ground Innings Date       Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
# MS Dhoni
mdf = dhoni_df[dhoni_df['Innings Player'] == 'MS Dhoni']

# %%
sum(mdf['Innings Runs Scored Num'])
# Out:
# 7581

# %%
# dhoni_df['Innings Player'].unique

# %%
len(mdf), len(sdf)
# Out:
# (203, 231)

# %%
# RPI - david, dhoni
sum(mdf['Innings Runs Scored Num'])/len(mdf), sum(sdf['Innings Runs Scored Num'])/len(sdf)
# Out:
# (37, 35)

# %%
# SR
100*sum(mdf['Innings Runs Scored Num'])/sum(mdf['Innings Balls Faced']), 100*sum(sdf['Innings Runs Scored Num'])/sum(sdf['Innings Balls Faced'])
# Out:
# (88, 70)

# %%
# 100's
sum(mdf["100's"]), sum(sdf["100's"])
# Out:
# (8.0, 11.0)

# %%
# 50's
sum(mdf["50's"]), sum(sdf["50's"])
# Out:
# (51.0, 61.0)

# %%
# Team Contribution - Runs Scored by each player, Runs by team
sum(mdf['Innings Runs Scored Num']), sum(sdf['Innings Runs Scored Num'])
# Out:
# (7581, 8247)

# %%
# 1997 - 2005 = All players
sum(david_df[david_df.Country == 'India']['Innings Runs Scored Num'])
# Out:
# 62147

# %%
# 2005 - 2013 = All players
sum(dhoni_df[dhoni_df.Country == 'India']['Innings Runs Scored Num'])
# Out:
# 58509

# %%
100*sum(mdf['Innings Runs Scored Num'])/sum(dhoni_df[dhoni_df.Country == 'India']['Innings Runs Scored Num'])
# Out:
# 12

# %%
100*sum(sdf['Innings Runs Scored Num'])/sum(david_df[david_df.Country == 'India']['Innings Runs Scored Num'])
# Out:
# 13

# %%
### visualizations:

# %%
david_df.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False).head(10)
# Out:
# Innings Player
# SC Ganguly         9829
# SR Tendulkar       9086
# R Dravid           8247
# MS Atapattu        7667
# JH Kallis          7650
# ST Jayasuriya      7581
# RT Ponting         7569
# AC Gilchrist       7511
# Inzamam-ul-Haq     7294
# Mohammad Yousuf    6934
# Name: Innings Runs Scored Num, dtype: int32

# %%
david_df.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False).head(10).plot(kind = 'barh')
plt.show()

# %%
dhoni_df.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False).head(10)
# Out:
# Innings Player
# KC Sangakkara       8677
# MS Dhoni            7581
# TM Dilshan          7150
# DPMD Jayawardene    6696
# MJ Clarke           6639
# AB de Villiers      6181
# RT Ponting          6167
# Yuvraj Singh        5639
# MEK Hussey          5425
# WU Tharanga         5218
# Name: Innings Runs Scored Num, dtype: int32

# %%
dhoni_df.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False).head(10).plot(kind = 'barh')
plt.show()

# %%
sdf.groupby(['year'])['Innings Runs Scored Num'].sum()
# Out:
# year
# 1997    951
# 1998    283
# 1999    1761
# 2000    980
# 2001    740
# 2002    913
# 2003    623
# 2004    1025
# 2005    971
# Name: Innings Runs Scored Num, dtype: int32

# %%
sdf.groupby(['year'])['Innings Runs Scored Num'].sum().plot(kind = 'bar')
plt.show()

# %%
mdf.groupby(['year'])['Innings Runs Scored Num'].sum()
# Out:
# year
# 2005    895
# 2006    821
# 2007    929
# 2008    1097
# 2009    1198
# 2010    600
# 2011    764
# 2012    524
# 2013    753
# Name: Innings Runs Scored Num, dtype: int32

# %%
mdf.groupby(['year'])['Innings Runs Scored Num'].sum().plot(kind = 'bar')
plt.show()

# %%
 ### Normalization:

# %%
# RPI - david, dhoni
sum(mdf['Innings Runs Scored Num'])/len(mdf), sum(sdf['Innings Runs Scored Num'])/len(sdf)
# Out:
# (37, 35)

# %%
# dhoni_df = player runs with dhoni
# player runs excluding dhoni => not_dhoni = dhoni_df[dhoni_df.player_name  != 'MS Dhoni']

# %%
# RPI - david, dhoni
sum(dhoni_df['Innings Runs Scored Num'])/len(dhoni_df)
# Out:
# 23

# %%
dhoni_df.head(1)
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number   Opposition     Ground Innings Date   Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
non_dhoni_df = dhoni_df[dhoni_df['Innings Player'] != 'MS Dhoni']

# %%
sum(non_dhoni_df['Innings Runs Scored Num'])/len(non_dhoni_df)
# Out:
# 23

# %%
non_david_df = david_df[david_df['Innings Player'] != 'R Dravid']

# %%
sum(non_david_df['Innings Runs Scored Num'])/len(non_david_df)
# Out:
# 22

# %%
# RPI - david, dhoni
sum(david_df['Innings Runs Scored Num'])/len(david_df)
# Out:
# 22

# %%
# Avg = 25 runs
# dhoni =  50

# %%
(sum(mdf['Innings Runs Scored Num'])/len(mdf))/(sum(non_dhoni_df['Innings Runs Scored Num'])/len(non_dhoni_df))
# Out:
# 1

# %%
(sum(sdf['Innings Runs Scored Num'])/len(sdf))/(sum(non_david_df['Innings Runs Scored Num'])/len(non_david_df))
# Out:
# 1

# %%
# dhoni => other
# SR = V = 93, other = 80, M/others , R/others
#  100's = Number of matches to score 100
# 50's = Number of matches to score 50
# Team contribution - m_con/other_con , r_con/other_con

# %%
# MSD = 50
203/51
# Out:
# 3

# %%
# MSD = 100
203/8
# Out:
# 25

# %%
# RD = 50
231/61
# Out:
# 3

# %%
# RD = 100
231/11
# Out:
# 21

# %%
100*sum(mdf['Innings Runs Scored Num'])/sum(mdf['Innings Balls Faced'])
# Out:
# 88

# %%
100*sum(non_dhoni_df['Innings Runs Scored Num'])/sum(non_dhoni_df['Innings Balls Faced'])
# Out:
# 79

# %%
88/79
# Out:
# 1

# %%
100*sum(sdf['Innings Runs Scored Num'])/sum(sdf['Innings Balls Faced'])
# Out:
# 70

# %%
100*sum(non_david_df['Innings Runs Scored Num'])/sum(non_david_df['Innings Balls Faced'])
# Out:
# 73

# %%
70/73
# Out:
# 0
